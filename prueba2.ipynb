# %%
from Sofascore import Sofascore
import json
import pandas as pd

# %%
sofascore = Sofascore()
match_id = 12437485

data = sofascore.get_player_ids(match_id)
# Out:
# Running

# %%
key_to_find = "id"
value_to_find = 12437485

# %%
data = sofascore.scrape_player_match_stats(match_id)
data
# Out:
# {'confirmed': True,
#  'home': {'players': [{'player': {'name': 'Karl Hein',
#      'slug': 'karl-hein',
#      'shortName': 'K. Hein',
#      'position': 'G',
#      'jerseyNumber': '13',
#      'height': 193,
#      'userCount': 4492,
#      'id': 991591,
#      'country': {'alpha2': 'EE',
#       'alpha3': 'EST',
#       'name': 'Estonia',
#       'slug': 'estonia'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1018656000,
#      'proposedMarketValueRaw': {'value': 2900000, 'currency': 'EUR'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'كارل هاين',
#        'hi': 'कार्ल हेन',
#        'bn': 'কার্ল হেইন'},
#       'shortNameTranslation': {'ar': 'ك. هاين',
#        'hi': 'के. हेन',
#        'bn': 'কে. হেইন'}}},
#     'teamId': 2534,
#     'shirtNumber': 13,
#     'jerseyNumber': '13',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'totalPass': 28,
#      'accuratePass': 21,
#      'totalLongBalls': 13,
# ...
