# %%
import requests
from bs4 import BeautifulSoup 
import json 

index = "https://www.laliga.com"

# %%
for num_pag in range(1, 31):
    url = f"https://www.laliga.com/es-GB/estadisticas/laliga-easports/goleadores/pagina/{num_pag}"

# %%
url = "https://www.laliga.com/es-GB/estadisticas/laliga-easports/goleadores/pagina/1"
resp = requests.get(url)

# %%
soup = BeautifulSoup(resp.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
names = soup.find_all(class_="styled__TdStyled-sc-57jgok-4 iPYsfW")

alias_laliga = []
nombre_laliga = []
enlace_jugador_laliga = []

for name in names: 
    a = name.find("a")
    if a.get("href").startswith("/es-GB/jugador/"):
        alias = a.get("href").split("/")[-1]
        alias_laliga.append(alias)

        enlace = a.get("href")
        enlace_jugador_laliga.append(enlace)

        response_jugador = requests.get(index + enlace)

        soup_player = BeautifulSoup(response_jugador.text, "html.parser")
        break


print(enlace_jugador_laliga)
soup_player
# Out:
# ['/es-GB/jugador/kylian-mbappe-lottin']
# <!DOCTYPE html>
# ...
